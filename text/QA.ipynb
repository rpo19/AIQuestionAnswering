# %% [markdown]
# # Imports and setup

# %%
### imports
from transformers import pipeline
import wikipediaapi
import pandas as pd
import sparql
import spacy_dbpedia_spotlight
import spacy

# %%
### SETUP
# the model is pretrained on SQuAD by default, but you can either specify it
# model_name = "deepset/roberta-base-squad2"
qa = pipeline("question-answering")

# model for dbpedia-spotlight
nlp = spacy.load('en_core_web_lg')
# TODO: check if it could be done without all the pipeline
nlp.add_pipe('dbpedia_spotlight', config={'language_code':'en', 'overwrite_ents':True})

# wikipedia api
wiki = wikipediaapi.Wikipedia(
        language='en',
        extract_format=wikipediaapi.ExtractFormat.WIKI
)

# %% [markdown]
# # Load data

# %%
# load LC-QALD
data = pd.read_json('../data/train-data.json')
data.head(5)
# Out:
#     _id                                 corrected_question  \
# 0  1501        How many movies did Stanley Kubrick direct?
# 1  2586              Which city's foundeer is John Forbes?
# 2  2653       What is the river whose mouth is in deadsea?
# 3  1055        What is the allegiance of John Kotelawala ?
# 4   705  How many races have the horses bred by Jacques...
#
#                                intermediary_question  \
# 0  How many <movies> are there whose <director> i...
# 1  What <city>'s <founded by> is <John Forbes (Br...
# 2  What is the <river> whose <river mouth> is <De...
# 3      What is the <allegiance> of John Kotelawala ?
# 4  What is the total number of <race> of the <rac...
#
#                                         sparql_query  sparql_template_id
# 0  SELECT DISTINCT COUNT(?uri) WHERE {?uri <http:...                 101
# 1  SELECT DISTINCT ?uri WHERE {?uri <http://dbped...                 301
# 2  SELECT DISTINCT ?uri WHERE {?uri <http://dbped...                 301
# 3   SELECT DISTINCT ?uri WHERE { <http://dbpedia....                   2
# 4  SELECT DISTINCT COUNT(?uri) WHERE { ?x <http:/...                 105

# %%
# filter simple questions and keep only questions and sparql queries
questions = data[data.sparql_template_id == 2][['corrected_question', 'sparql_query']]
# REMOVE NEXT LINE
#questions = questions.head(20)

# %% [markdown]
# # Prepare data

# %% [markdown]
# ## Extract answers

# %%
# extract answer from dbpedia endpoint
def get_answers(query, endpoint = 'http://dbpedia.org/sparql'):
    answers = []
    results = sparql.query(endpoint, query)
    for row in results:
        answers.append(sparql.unpack_row(row)[0])        
    return answers

# %%
questions['answer'] = questions['sparql_query'].apply(get_answers)

# %%
# TODO: be sure to have fixed get_answers to avoid this operation
# questions['answers'] = questions['answers'].apply(lambda x: [item for sublist in x for item in sublist])

# %%
# questions['answer'] = questions['answer'].apply(lambda x : [' '.join(item.split('/')[-1].split('_')) for item in x])

# %%
# save questions
questions.to_csv('../data/questions.csv')

# %% [markdown]
# ## Extract dbpedia entities

# %%
def get_entities(question):
    # entity extraction and dbpedia linking
    try:
        # TODO: fix error
        tmp = nlp(question)
    except:
        ent = 'SpacyError'
        return ent

    # check results
    if len(tmp.ents) == 0:
        ent = 'NotFound'
    else:
        # TODO: i'm not sure on what happens if there are more than one ents :/
        # maybe in an english question the subject is always the last entity... 
        ent = tmp.ents[-1].text # change [0] to [-1]? seems better...
    return ent


# test
get_entities(questions.loc[3966]['corrected_question'])
# Out:
# 'Purnima Banerjee'

# %%
# store entities
questions['entity'] = questions['corrected_question'].apply(get_entities)
questions
# Out:
#                                      corrected_question  \
# 3           What is the allegiance of John Kotelawala ?
# 6                 What is the region of Tom Perriello ?
# 9                   Name the mascot of Austin College ?
# 13                    Name the origin of Henry Cluney ?
# 19    Name the resting place of Charles Edward Magoon ?
# ...                                                 ...
# 3966  What is the political party to which Purnima B...
# 3972  What is the currency of Republic of Montenegro...
# 3974               What is the club of Perianne Jones ?
# 3994  List all the mmebers of  Mekong River Commission?
# 3999        List the team for which Doug Acomb played ?
#
#                                            sparql_query  \
# 3      SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 6      SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 9      SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 13     SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 19     SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# ...                                                 ...
# 3966   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3972   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3974   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3994   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3999   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
#
#                                                  answer  \
# 3               [http://dbpedia.org/resource/Sri_Lanka]
# 6                                                    []
# 9                [http://dbpedia.org/resource/Kangaroo]
# 13    [http://dbpedia.org/resource/Northern_Ireland,...
# 19    [http://dbpedia.org/resource/Lincoln,_Nebraska...
# ...                                                 ...
# 3966  [http://dbpedia.org/resource/Indian_National_C...
# 3972                                                 []
# 3974                               [Nakkertok Ski Club]
# 3994  [http://dbpedia.org/resource/Cambodia, http://...
# 3999  [http://dbpedia.org/resource/Toronto_Maple_Leafs]
#
#                        entity
# 3             John Kotelawala
# 6               Tom Perriello
# 9              Austin College
# 13               Henry Cluney
# 19      Charles Edward Magoon
# ...                       ...
# 3966         Purnima Banerjee
# 3972               Montenegro
# 3974           Perianne Jones
# 3994  Mekong River Commission
# 3999               Doug Acomb
#
# [597 rows x 4 columns]

# %%
# entities = []
# for _, row in questions.iterrows():
#     # entity extraction and dbpedia linking
#     print(row['corrected_question'])
#     # TODO: fix the error
#     tmp = nlp(row['corrected_question'])
#     # check results
#     if len(tmp.ents) == 0:
#         ent = 'NotFound'
#     else:
#         # TODO: i'm not sure on what happens if there are more than one ents :/
#         ent = tmp.ents[0].text

# entities.append(ent)

# %%
# save questions
questions.to_csv('../data/questions.csv')

# %%
# check inconsistent records
inconsistent = questions[(questions['entity'].isin(['NotFound', 'SpacyError'])) | (len(questions['answer']) == 0)]
print('Invalid records: ', len(inconsistent))
inconsistent
# Out:
# Invalid records:  30
#                                      corrected_question  \
# 99              Where is the swedish covenant hospital?
# 143   Which driver came first in the 1993 European G...
# 220                 Who built the Ford Y-block engine ?
# 270    What is Bob Adams (American football) known for?
# 366   which politician is currently ruling over Rish...
# 380                       Name the monarch of L Buwei ?
# 519                Who is the writer of He's a Pirate ?
# 596              Who created the world series of Poker?
# 784       which person created the women in the garden?
# 790          List the main ingredient of Pizza-ghetti ?
# 893   Which minister was responsible for Kriminalpol...
# 920          What are on the borders of Shimsa Plateau?
# 1104       What is the affiliation of tani University ?
# 1224  Name the driver who had a pole finish in 1989 ...
# 1425                  Name the source Island of Bayou ?
# 1896              What are the Languages of Zabbaleen ?
# 1943             Where did ed podolak go to high school
# 1973                     Where did john o conner study?
# 2187  Who is the Pole driver of 1992 Canadian Grand ...
# 2236  Who is the builder of Presidio Santa Cruz de T...
# 2628     List down the important people of The Elders ?
# 2802             where are renaissance centers located?
# 2918  From where did Ben Wilson (American football) ...
# 2968          Who were the producers of the tenderfoot?
# 3045                 Who was the narrator in the point?
# 3086    Name the musical band of Written in the Stars ?
# 3296               What is the area of ITV (Thailand) ?
# 3437             What is the content license of Darcs ?
# 3586                    Who produced wizards vs aliens?
# 3885  Who is the Pole driver of 1997 Canadian Grand ...
#
#                                            sparql_query  \
# 99     SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 143    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 220    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 270    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 366    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 380    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 519    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 596    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 784    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 790    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 893    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 920    SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 1104   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 1224   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 1425   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 1896   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 1943   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 1973   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 2187   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 2236   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 2628   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 2802   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 2918   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 2968   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3045   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3086   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3296   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3437   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3586   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
# 3885   SELECT DISTINCT ?uri WHERE { <http://dbpedia....
#
#                                                  answer      entity
# 99                                                   []    NotFound
# 143          [http://dbpedia.org/resource/Ayrton_Senna]  SpacyError
# 220    [http://dbpedia.org/resource/Ford_Motor_Company]  SpacyError
# 270   [http://dbpedia.org/resource/National_Football...  SpacyError
# 366                                                  []    NotFound
# 380                                                  []    NotFound
# 519   [http://dbpedia.org/resource/Hans_Zimmer, Klau...    NotFound
# 596   [http://dbpedia.org/resource/United_States, ht...    NotFound
# 784                                                  []    NotFound
# 790                                                  []    NotFound
# 893                                                  []    NotFound
# 920                                                  []    NotFound
# 1104             [http://dbpedia.org/resource/Buddhism]    NotFound
# 1224         [http://dbpedia.org/resource/Ayrton_Senna]  SpacyError
# 1425                                                 []    NotFound
# 1896      [http://dbpedia.org/resource/Egyptian_Arabic]    NotFound
# 1943  [http://dbpedia.org/resource/Atlantic_High_Sch...    NotFound
# 1973                                                 []    NotFound
# 2187         [http://dbpedia.org/resource/Ayrton_Senna]  SpacyError
# 2236                [http://dbpedia.org/resource/Spain]  SpacyError
# 2628  [http://dbpedia.org/resource/Mary_Robinson, Da...    NotFound
# 2802  [400, http://dbpedia.org/resource/Detroit, htt...    NotFound
# 2918  [http://dbpedia.org/resource/Carver_High_Schoo...  SpacyError
# 2968                                                 []    NotFound
# 3045  [http://dbpedia.org/resource/Alan_Thicke, http...    NotFound
# 3086                                                 []    NotFound
# 3296             [http://dbpedia.org/resource/Thailand]  SpacyError
# 3437                  [http://dbpedia.org/resource/GNU]    NotFound
# 3586        [http://dbpedia.org/resource/Brian_Minchin]    NotFound
# 3885   [http://dbpedia.org/resource/Michael_Schumacher]  SpacyError

# %% [markdown]
# # QA on wikipedia

# %%
# load data to avoid executing the blocks above
questions = pd.read_csv('../data/questions.csv', index_col = 0)
questions.head(5)

# %%
# TODO: fix return values
def search_answer(question, entity, debug = False):
    # get wikipedia page
    p = wiki.page(entity)
    
    # iterate on sections and find answer in each span
    max_score = 0
    best_answer = None
    for section in p.sections:

        # TODO: how to identify a smaller span? (check if it's necessary...)
        # if subject in section.text: # look only in relevant sections???
        
        # exlude last section
        if section.title != 'External links':
            if debug: print(section.title)
            context = section.text
            # exlude empty sections (i.e. macro section intestation)
            if context != '':
                answer = qa(question=question, context=context)
                if answer['score'] > max_score:
                    max_score = answer['score']
                    best_answer = answer
                if debug: print(f"Answer: '{answer['answer']}' with score {answer['score']}", '\n', 10*'#')
                

    # print best answer
    if best_answer is not None:  
        if debug: print(f"BEST ANSWER: '{best_answer['answer']}' with score {best_answer['score']}")
    else:
        best_answer = 'Sorry, answer not found!'
        if debug: print(best_answer)
    return best_answer

# %%
# test a question
example = questions.iloc[110]

print('# QUESTION:\n', example['corrected_question'])
print('# SPARQL:\n', example['sparql_query'])
print('# POSSIBLE ANSWERS:\n', example['answer'])
print('_'*30)

search_answer(example['corrected_question'], example['entity'], debug = True)
# Out:
# # QUESTION:
#  What are the houses of Parliament Security Services ?
# # SPARQL:
#   SELECT DISTINCT ?uri WHERE { <http://dbpedia.org/resource/Parliament_Security_Services> <http://dbpedia.org/property/houses> ?uri }
# # POSSIBLE ANSWERS:
#  ['http://dbpedia.org/resource/Rajya_Sabha', 'http://dbpedia.org/resource/Lok_Sabha', '']
# ______________________________
# 'Sorry, answer not found!'

# %%
answers = []
for index, row in questions.iterrows():
    answers.append(search_answer(row['corrected_question'], row['entity']))

# %%
answers
# Out:
# [{'score': 0.9133368134498596,
#   'start': 53,
#   'end': 70,
#   'answer': 'political leaders'},
#  {'score': 0.9734827876091003,
#   'start': 71,
#   'end': 83,
#   'answer': 'Sierra Leone'},
#  {'score': 0.9678401350975037,
#   'start': 1438,
#   'end': 1451,
#   'answer': 'David Peeples'},
#  'Sorry, answer not found!',
#  {'score': 0.80088871717453, 'start': 36, 'end': 40, 'answer': 'Cuba'},
#  {'score': 0.9982991218566895, 'start': 693, 'end': 701, 'answer': 'He Kexin'},
#  {'score': 0.614020049571991,
#   'start': 1726,
#   'end': 1753,
#   'answer': 'Chief Justice John Marshall'},
#  {'score': 0.5060786604881287,
#   'start': 14,
#   'end': 55,
#   'answer': 'Recipient of the Grand Order of Mugunghwa'},
#  'Sorry, answer not found!',
#  {'score': 0.8656526803970337, 'start': 607, 'end': 614, 'answer': 'Chinese'},
#  {'score': 0.1327703446149826,
#   'start': 192,
#   'end': 225,
#   'answer': 'Everything\nTelevision Supervision'},
#  {'score': 0.9831961393356323,
#   'start': 479,
#   'end': 491,
#   'answer': 'Selena Gomez'},
#  {'score': 0.529830276966095,
#   'start': 133,
#   'end': 158,
#   'answer': 'Gulf Coast Television Ltd'},
#  {'score': 0.933255672454834, 'start': 335, 'end': 338, 'answer': 'UCR'},
#  'Sorry, answer not found!',
#  {'score': 0.7743380069732666,
#   'start': 578,
#   'end': 615,
#   'answer': 'San Fransokyo Institute of Technology'},
#  'Sorry, answer not found!',
#  {'score': 0.00805633794516325,
#   'start': 419,
#   'end': 433,
#   'answer': 'Gaia Principle'},
#  {'score': 0.31716781854629517,
#   'start': 83,
#   'end': 142,
#   'answer': "People's Television Network\nPhilippine Broadcasting Service"},
#  {'score': 0.509458065032959, 'start': 0, 'end': 6, 'answer': 'Toyota'},
#  {'score': 0.30411216616630554,
#   'start': 74,
#   'end': 105,
#   'answer': 'Secret Path to Oscar Qualifying'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.677361786365509,
#   'start': 68,
#   'end': 102,
#   'answer': 'Robert F. Kennedy Memorial Stadium'},
#  {'score': 0.9300763010978699,
#   'start': 646,
#   'end': 669,
#   'answer': 'Jean-Jacques Dessalines'},
#  {'score': 0.341845840215683, 'start': 0, 'end': 4, 'answer': 'List'},
#  {'score': 0.11970401555299759,
#   'start': 802,
#   'end': 810,
#   'answer': 'Tasmania'},
#  {'score': 0.6108472943305969, 'start': 12, 'end': 20, 'answer': 'Ethiopia'},
#  {'score': 0.8835289478302002,
#   'start': 90,
#   'end': 107,
#   'answer': 'Anna Nicole Smith'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.8531383872032166,
#   'start': 510,
#   'end': 524,
#   'answer': 'command center'},
#  {'score': 0.8259701132774353,
#   'start': 5,
#   'end': 19,
#   'answer': 'External links'},
#  'Sorry, answer not found!',
#  {'score': 0.5410442352294922, 'start': 216, 'end': 220, 'answer': 'East'},
#  {'score': 0.6725258827209473,
#   'start': 2822,
#   'end': 2835,
#   'answer': 'Dwight Howard'},
#  {'score': 0.3441932797431946,
#   'start': 32,
#   'end': 69,
#   'answer': 'United States Numbered Bicycle Routes'},
#  'Sorry, answer not found!',
#  {'score': 0.3857582211494446,
#   'start': 199,
#   'end': 234,
#   'answer': 'Robert E. Wood with Montgomery Ward'},
#  {'score': 0.2768760919570923,
#   'start': 107,
#   'end': 137,
#   'answer': 'Detecting package dependencies'},
#  {'score': 0.9556924104690552, 'start': 0, 'end': 6, 'answer': 'Moscow'},
#  {'score': 0.9863232970237732,
#   'start': 170,
#   'end': 183,
#   'answer': 'Ukrtransstroi'},
#  'Sorry, answer not found!',
#  {'score': 0.9058400988578796,
#   'start': 59,
#   'end': 82,
#   'answer': 'Martin Hoberg Hedegaard'},
#  {'score': 0.5344670414924622, 'start': 344, 'end': 352, 'answer': 'the Army'},
#  {'score': 0.3486277759075165,
#   'start': 298,
#   'end': 334,
#   'answer': 'McCarran International Airport (LAS)'},
#  {'score': 0.873084545135498,
#   'start': 352,
#   'end': 365,
#   'answer': 'wine drinkers'},
#  {'score': 0.1978229582309723,
#   'start': 440,
#   'end': 452,
#   'answer': 'eastern half'},
#  'Sorry, answer not found!',
#  {'score': 0.4939979314804077,
#   'start': 0,
#   'end': 21,
#   'answer': '2002 General Election'},
#  {'score': 0.9601272344589233,
#   'start': 96,
#   'end': 116,
#   'answer': 'Callisto Corporation'},
#  'Sorry, answer not found!',
#  {'score': 0.942675769329071, 'start': 100, 'end': 106, 'answer': 'Israel'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.6312282085418701,
#   'start': 598,
#   'end': 619,
#   'answer': 'Harry Potter universe'},
#  {'score': 0.39319923520088196,
#   'start': 51,
#   'end': 89,
#   'answer': 'Sanford N. McDonnell\nHarry Stonecipher'},
#  {'score': 0.6901467442512512, 'start': 2384, 'end': 2390, 'answer': 'Cicero'},
#  {'score': 0.5025767683982849, 'start': 71, 'end': 78, 'answer': 'Italian'},
#  {'score': 0.9660519957542419, 'start': 146, 'end': 151, 'answer': 'white'},
#  'Sorry, answer not found!',
#  {'score': 0.29739195108413696,
#   'start': 562,
#   'end': 575,
#   'answer': 'Bart and Lisa'},
#  {'score': 0.9541870951652527,
#   'start': 0,
#   'end': 19,
#   'answer': 'Thomas Tudor Tucker'},
#  {'score': 0.24802172183990479,
#   'start': 0,
#   'end': 39,
#   'answer': 'Winterland (disambiguation)\nWonderworld'},
#  {'score': 0.9402757287025452,
#   'start': 268,
#   'end': 279,
#   'answer': 'Neil Gaiman'},
#  {'score': 0.8971775770187378,
#   'start': 755,
#   'end': 806,
#   'answer': 'English Theater and the Multicultural Mediterranean'},
#  {'score': 0.8815100193023682, 'start': 31, 'end': 39, 'answer': 'sangkats'},
#  {'score': 0.6162480115890503,
#   'start': 5,
#   'end': 19,
#   'answer': 'External links'},
#  {'score': 0.9735592603683472,
#   'start': 126,
#   'end': 138,
#   'answer': 'Medley Relay'},
#  {'score': 0.894519031047821,
#   'start': 1335,
#   'end': 1348,
#   'answer': 'New York Mets'},
#  {'score': 0.9821351170539856,
#   'start': 579,
#   'end': 590,
#   'answer': 'Mario Cuomo'},
#  'Sorry, answer not found!',
#  {'score': 0.25208160281181335,
#   'start': 491,
#   'end': 512,
#   'answer': 'Universal Music Group'},
#  'Sorry, answer not found!',
#  {'score': 0.7336572408676147,
#   'start': 219,
#   'end': 229,
#   'answer': 'pragmatist'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.9709593057632446,
#   'start': 6342,
#   'end': 6355,
#   'answer': 'Massachusetts'},
#  {'score': 0.44264712929725647,
#   'start': 91,
#   'end': 121,
#   'answer': 'Pacific, Asia and the Americas'},
#  {'score': 0.26483675837516785,
#   'start': 103,
#   'end': 124,
#   'answer': 'East and West Tilbury'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.551985502243042,
#   'start': 0,
#   'end': 30,
#   'answer': 'Cloud computing security\nCloud'},
#  {'score': 0.21752694249153137,
#   'start': 18,
#   'end': 38,
#   'answer': "New York\nKieft's War"},
#  {'score': 0.10367412120103836, 'start': 706, 'end': 713, 'answer': 'Buffalo'},
#  {'score': 0.9756729006767273,
#   'start': 879,
#   'end': 889,
#   'answer': 'John Burns'},
#  {'score': 0.529811441898346,
#   'start': 318,
#   'end': 347,
#   'answer': 'racing class\nFormula Regional'},
#  {'score': 0.36170119047164917,
#   'start': 215,
#   'end': 234,
#   'answer': 'New York politician'},
#  {'score': 0.5057421326637268,
#   'start': 62,
#   'end': 79,
#   'answer': 'Daund–Manmad line'},
#  {'score': 0.988734245300293,
#   'start': 29,
#   'end': 45,
#   'answer': 'Meadowbrook Pond'},
#  'Sorry, answer not found!',
#  {'score': 0.964265763759613, 'start': 548, 'end': 550, 'answer': 'VU'},
#  {'score': 0.07666890323162079, 'start': 821, 'end': 828, 'answer': 'Chinese'},
#  {'score': 0.14194893836975098,
#   'start': 1350,
#   'end': 1361,
#   'answer': 'Boston area'},
#  {'score': 0.9500566124916077,
#   'start': 279,
#   'end': 290,
#   'answer': 'Andrew Weil'},
#  {'score': 0.8931292295455933,
#   'start': 0,
#   'end': 40,
#   'answer': 'Slow Train Coming\nSaved\nEmpire Burlesque'},
#  {'score': 0.5909218192100525,
#   'start': 0,
#   'end': 29,
#   'answer': 'Olympiacos\n Red Star Belgrade'},
#  {'score': 0.8472681045532227,
#   'start': 39,
#   'end': 56,
#   'answer': 'traditional chess'},
#  'Sorry, answer not found!',
#  {'score': 0.9971022009849548, 'start': 723, 'end': 731, 'answer': 'Bob Iger'},
#  {'score': 0.8955062627792358,
#   'start': 13,
#   'end': 36,
#   'answer': 'Hermes Airports Limited'},
#  {'score': 0.6275186538696289, 'start': 28, 'end': 34, 'answer': 'racing'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.9990248680114746,
#   'start': 340,
#   'end': 349,
#   'answer': 'Bob Dylan'},
#  'Sorry, answer not found!',
#  {'score': 0.6673934459686279,
#   'start': 407,
#   'end': 428,
#   'answer': 'Yale University Press'},
#  {'score': 0.6631585955619812, 'start': 22, 'end': 26, 'answer': 'Bogë'},
#  'Sorry, answer not found!',
#  {'score': 0.9462552070617676,
#   'start': 0,
#   'end': 12,
#   'answer': 'Bill Clinton'},
#  {'score': 0.057023320347070694, 'start': 74, 'end': 78, 'answer': '1983'},
#  'Sorry, answer not found!',
#  {'score': 0.08022767305374146,
#   'start': 0,
#   'end': 15,
#   'answer': 'Sex strike\nList'},
#  {'score': 0.6793863773345947,
#   'start': 21,
#   'end': 37,
#   'answer': 'a work of poetry'},
#  {'score': 0.28622835874557495,
#   'start': 0,
#   'end': 40,
#   'answer': 'Band and Jazz Band\nChoir\nOrchestra\nDrama'},
#  {'score': 0.8852171301841736,
#   'start': 125,
#   'end': 134,
#   'answer': 'shortwave'},
#  {'score': 0.9853492975234985,
#   'start': 37,
#   'end': 55,
#   'answer': 'Kanlapapruek Depot'},
#  'Sorry, answer not found!',
#  {'score': 0.43637052178382874,
#   'start': 22,
#   'end': 33,
#   'answer': 'veal dishes'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.9636437296867371,
#   'start': 1352,
#   'end': 1384,
#   'answer': 'Argentina and the Canary Islands'},
#  {'score': 0.8835912346839905,
#   'start': 190,
#   'end': 210,
#   'answer': 'legends and folklore'},
#  {'score': 0.9912551045417786, 'start': 284, 'end': 290, 'answer': 'Tehran'},
#  {'score': 0.991934061050415,
#   'start': 256,
#   'end': 266,
#   'answer': 'Mike White'},
#  'Sorry, answer not found!',
#  {'score': 0.17409279942512512,
#   'start': 8,
#   'end': 37,
#   'answer': 'magister militum per Armeniam'},
#  {'score': 0.14983081817626953,
#   'start': 314,
#   'end': 378,
#   'answer': 'Handles Playboy trademarks on apparel, accessories, collectibles'},
#  {'score': 0.493509978055954, 'start': 22, 'end': 33, 'answer': 'Junior Kiwi'},
#  {'score': 0.03955395147204399,
#   'start': 268,
#   'end': 312,
#   'answer': 'CBS and the Warner Bros. unit of Time Warner'},
#  {'score': 0.9008572697639465,
#   'start': 300,
#   'end': 330,
#   'answer': 'Creative Commons and Hunch.com'},
#  {'score': 0.9721807241439819, 'start': 0, 'end': 9, 'answer': 'John Ryan'},
#  {'score': 0.5988233089447021,
#   'start': 0,
#   'end': 20,
#   'answer': 'Footnotes\n\nCitations'},
#  {'score': 0.6158998608589172,
#   'start': 1271,
#   'end': 1298,
#   'answer': 'Crosby, Nichols and Company'},
#  {'score': 0.9817923903465271,
#   'start': 1264,
#   'end': 1278,
#   'answer': 'Happy Holidays'},
#  {'score': 0.8075675964355469,
#   'start': 5,
#   'end': 19,
#   'answer': 'External links'},
#  {'score': 0.9833880662918091, 'start': 180, 'end': 185, 'answer': 'Helen'},
#  {'score': 0.14339818060398102,
#   'start': 4,
#   'end': 23,
#   'answer': 'Seattle Great Wheel'},
#  {'score': 0.6895824074745178, 'start': 9, 'end': 19, 'answer': 'References'},
#  {'score': 0.6273418664932251,
#   'start': 13,
#   'end': 24,
#   'answer': 'Tour Finals'},
#  {'score': 0.6240653991699219,
#   'start': 37,
#   'end': 58,
#   'answer': 'Outline of Madagascar'},
#  {'score': 0.8470871448516846,
#   'start': 209,
#   'end': 225,
#   'answer': 'right-hand drive'},
#  {'score': 0.9171686172485352,
#   'start': 298,
#   'end': 314,
#   'answer': 'Peachtree Street'},
#  {'score': 0.22534914314746857,
#   'start': 121,
#   'end': 140,
#   'answer': 'Lokomotiv Yaroslavl'},
#  {'score': 0.5437237024307251, 'start': 0, 'end': 10, 'answer': 'The M40B16'},
#  {'score': 0.8084275126457214,
#   'start': 737,
#   'end': 756,
#   'answer': 'Governor Strickland'},
#  {'score': 0.8916335105895996,
#   'start': 1711,
#   'end': 1718,
#   'answer': 'Everett'},
#  {'score': 0.9949212670326233, 'start': 156, 'end': 162, 'answer': 'Brunei'},
#  {'score': 0.9023873209953308, 'start': 34, 'end': 44, 'answer': 'Republican'},
#  {'score': 0.7923758625984192,
#   'start': 325,
#   'end': 354,
#   'answer': 'music, dance, arts and sports'},
#  {'score': 0.4406808018684387, 'start': 197, 'end': 202, 'answer': 'Bronx'},
#  {'score': 0.8690752387046814, 'start': 4, 'end': 15, 'answer': 'gas station'},
#  {'score': 0.7005838751792908,
#   'start': 1067,
#   'end': 1083,
#   'answer': 'Columbia Plateau'},
#  {'score': 0.8715493679046631, 'start': 0, 'end': 8, 'answer': 'Burnside'},
#  'Sorry, answer not found!',
#  {'score': 0.8769847750663757,
#   'start': 291,
#   'end': 309,
#   'answer': 'Saints for Dummies'},
#  {'score': 0.9988142848014832, 'start': 8, 'end': 15, 'answer': 'Atlanta'},
#  {'score': 0.20461031794548035,
#   'start': 19,
#   'end': 29,
#   'answer': 'References'},
#  'Sorry, answer not found!',
#  {'score': 0.43784573674201965,
#   'start': 829,
#   'end': 843,
#   'answer': 'border neutral'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.34034353494644165,
#   'start': 111,
#   'end': 132,
#   'answer': 'Gordon\nJustice Gordon'},
#  'Sorry, answer not found!',
#  {'score': 0.9294120669364929,
#   'start': 57,
#   'end': 84,
#   'answer': 'Highbury Preparatory School'},
#  {'score': 0.7289078831672668,
#   'start': 3308,
#   'end': 3322,
#   'answer': 'Carroll Shelby'},
#  {'score': 0.3487497866153717, 'start': 5, 'end': 13, 'answer': 'See also'},
#  {'score': 0.9989215135574341,
#   'start': 9,
#   'end': 23,
#   'answer': 'John McCutchan'},
#  {'score': 0.8526991009712219,
#   'start': 300,
#   'end': 317,
#   'answer': 'Mumbai and Karwar'},
#  {'score': 0.7340043783187866,
#   'start': 274,
#   'end': 317,
#   'answer': 'soccer football, basketball, and volleyball'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.35220810770988464, 'start': 0, 'end': 6, 'answer': 'London'},
#  {'score': 0.7061958909034729, 'start': 60, 'end': 64, 'answer': 'SKAI'},
#  {'score': 0.09290482103824615, 'start': 174, 'end': 181, 'answer': 'Ireland'},
#  'Sorry, answer not found!',
#  {'score': 0.6036765575408936,
#   'start': 328,
#   'end': 372,
#   'answer': 'government-sponsored family planning program'},
#  {'score': 0.9599165320396423, 'start': 18, 'end': 28, 'answer': 'Washington'},
#  {'score': 0.7898134589195251, 'start': 121, 'end': 129, 'answer': 'Thirteen'},
#  {'score': 0.18729767203330994,
#   'start': 0,
#   'end': 100,
#   'answer': 'Rocket and mortar attacks on southern Israel\nPalestinian casualties of war\nIsraeli casualties of war'},
#  {'score': 0.6956149935722351,
#   'start': 985,
#   'end': 1011,
#   'answer': 'Roskilde Festival, Denmark'},
#  {'score': 0.9871118664741516, 'start': 60, 'end': 68, 'answer': 'Pakistan'},
#  {'score': 0.2944776117801666,
#   'start': 17,
#   'end': 95,
#   'answer': 'Miss Universe 2008 due to Rodríguez being underage  and finished in the Top 10'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.9845499396324158,
#   'start': 20,
#   'end': 35,
#   'answer': 'Thomas S. Hinde'},
#  {'score': 0.34687355160713196,
#   'start': 33,
#   'end': 45,
#   'answer': 'Mary Poppins'},
#  {'score': 0.927560567855835,
#   'start': 35,
#   'end': 55,
#   'answer': 'Yuri Gagarin Academy'},
#  {'score': 0.6086945533752441, 'start': 28, 'end': 32, 'answer': 'Baku'},
#  {'score': 0.9074928760528564, 'start': 160, 'end': 165, 'answer': 'India'},
#  'Sorry, answer not found!',
#  {'score': 0.9398050904273987,
#   'start': 410,
#   'end': 419,
#   'answer': 'Ramai Deo'},
#  {'score': 0.8927449584007263, 'start': 464, 'end': 467, 'answer': '575'},
#  {'score': 0.009556714445352554,
#   'start': 61,
#   'end': 120,
#   'answer': 'Phase out all subsidies for fossil fuels and nuclear energy'},
#  {'score': 0.9767930507659912,
#   'start': 283,
#   'end': 301,
#   'answer': 'Sir Ninian Stephen'},
#  {'score': 0.9986048340797424,
#   'start': 47,
#   'end': 68,
#   'answer': 'George Cary Eggleston'},
#  'Sorry, answer not found!',
#  {'score': 0.6782005429267883,
#   'start': 1146,
#   'end': 1167,
#   'answer': 'central North America'},
#  {'score': 0.9820570945739746,
#   'start': 17,
#   'end': 30,
#   'answer': 'Jane Hannaway'},
#  {'score': 0.41380566358566284,
#   'start': 1056,
#   'end': 1064,
#   'answer': 'Budapest'},
#  'Sorry, answer not found!',
#  {'score': 0.7231013178825378, 'start': 92, 'end': 101, 'answer': 'guitarist'},
#  {'score': 0.6951099038124084,
#   'start': 212,
#   'end': 236,
#   'answer': 'Thames Haven and Coryton'},
#  {'score': 0.5962046384811401,
#   'start': 3155,
#   'end': 3166,
#   'answer': 'Victory Day'},
#  {'score': 0.914551854133606,
#   'start': 233,
#   'end': 244,
#   'answer': 'Proof66.com'},
#  {'score': 0.286342591047287,
#   'start': 51,
#   'end': 65,
#   'answer': 'German cuisine'},
#  {'score': 0.9721397161483765, 'start': 554, 'end': 560, 'answer': 'Danish'},
#  {'score': 0.2179800271987915,
#   'start': 88,
#   'end': 129,
#   'answer': 'Rajkiye Buniyadi Ms Panki School\nSarswati'},
#  'Sorry, answer not found!',
#  {'score': 0.15166419744491577,
#   'start': 43,
#   'end': 66,
#   'answer': 'Melanophobia\nRich black'},
#  {'score': 0.741238534450531,
#   'start': 170,
#   'end': 195,
#   'answer': 'Gray Marine Motor Company'},
#  'Sorry, answer not found!',
#  {'score': 0.3836037814617157,
#   'start': 254,
#   'end': 304,
#   'answer': 'information, education, culture, and entertainment'},
#  {'score': 0.8348804116249084, 'start': 97, 'end': 105, 'answer': 'Morbihan'},
#  {'score': 0.9874049425125122,
#   'start': 69,
#   'end': 84,
#   'answer': 'David Jefferies'},
#  {'score': 0.9069534540176392,
#   'start': 4169,
#   'end': 4178,
#   'answer': 'Fort Pitt'},
#  {'score': 0.9521963000297546, 'start': 116, 'end': 122, 'answer': 'France'},
#  {'score': 0.9937368631362915, 'start': 164, 'end': 172, 'answer': 'class IV'},
#  {'score': 0.24145224690437317,
#   'start': 315,
#   'end': 348,
#   'answer': 'Looking at the growth of the game'},
#  {'score': 0.06618373095989227,
#   'start': 45,
#   'end': 112,
#   'answer': 'Azerbaijan\nHeydar Aliyev Palace, a concert hall in Baku, Azerbaijan'},
#  'Sorry, answer not found!',
#  {'score': 0.5966715812683105,
#   'start': 24,
#   'end': 47,
#   'answer': 'Football\nFootball field'},
#  {'score': 0.4979906678199768,
#   'start': 0,
#   'end': 47,
#   'answer': 'Chief Coastguard\nMaritime Security Regimes\nPort'},
#  {'score': 0.5916539430618286,
#   'start': 87,
#   'end': 103,
#   'answer': 'Bogorodsky Uyezd'},
#  'Sorry, answer not found!',
#  {'score': 0.9798225164413452, 'start': 19, 'end': 24, 'answer': 'Korea'},
#  {'score': 0.8931147456169128,
#   'start': 0,
#   'end': 17,
#   'answer': 'International Day'},
#  {'score': 0.6787541508674622,
#   'start': 99,
#   'end': 115,
#   'answer': 'Panthera spelaea'},
#  {'score': 0.6480328440666199, 'start': 482, 'end': 486, 'answer': 'Thai'},
#  {'score': 0.4280557334423065,
#   'start': 0,
#   'end': 62,
#   'answer': 'Alliance for Affordable Internet\nGoogle Free Zone\nInternet.org'},
#  {'score': 0.3167162537574768,
#   'start': 87,
#   'end': 105,
#   'answer': 'Capitolio Nacional'},
#  {'score': 0.647627592086792,
#   'start': 0,
#   'end': 18,
#   'answer': 'As of 14 June 2019'},
#  {'score': 0.11289212852716446,
#   'start': 96,
#   'end': 129,
#   'answer': 'Roman Catholic Diocese of Balanga'},
#  {'score': 0.7231342792510986,
#   'start': 160,
#   'end': 175,
#   'answer': 'Ludhiana, India'},
#  {'score': 0.8588224053382874,
#   'start': 4370,
#   'end': 4385,
#   'answer': 'Samajwadi Party'},
#  {'score': 0.9968188405036926,
#   'start': 380,
#   'end': 396,
#   'answer': 'Heinrich Himmler'},
#  {'score': 0.08585610240697861,
#   'start': 0,
#   'end': 18,
#   'answer': 'List of Arab towns'},
#  {'score': 0.5626980066299438,
#   'start': 742,
#   'end': 763,
#   'answer': 'glass making industry'},
#  {'score': 0.7809198498725891,
#   'start': 38,
#   'end': 66,
#   'answer': 'Wild Atlantic Way\nGalway Bay'},
#  {'score': 0.5638313889503479,
#   'start': 2471,
#   'end': 2483,
#   'answer': 'Temple Mount'},
#  {'score': 0.9819600582122803,
#   'start': 605,
#   'end': 615,
#   'answer': 'Sibselmash'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.620745837688446,
#   'start': 98,
#   'end': 129,
#   'answer': 'American Academy of Achievement'},
#  {'score': 0.9574363231658936,
#   'start': 331,
#   'end': 345,
#   'answer': 'Richard Rogers'},
#  {'score': 0.905721127986908, 'start': 154, 'end': 161, 'answer': 'Medford'},
#  {'score': 0.7244011759757996, 'start': 0, 'end': 7, 'answer': 'Berezan'},
#  'Sorry, answer not found!',
#  {'score': 0.37848225235939026,
#   'start': 103,
#   'end': 125,
#   'answer': 'Word 1.0 for Macintosh'},
#  {'score': 0.3117595911026001,
#   'start': 0,
#   'end': 44,
#   'answer': 'European Atlas of the Seas\nList of languages'},
#  {'score': 0.7912616729736328,
#   'start': 155,
#   'end': 168,
#   'answer': 'Anaheim Ducks'},
#  'Sorry, answer not found!',
#  {'score': 0.12378635257482529,
#   'start': 207,
#   'end': 235,
#   'answer': 'Horserace Betting Levy Board'},
#  'Sorry, answer not found!',
#  {'score': 0.9547786712646484,
#   'start': 78,
#   'end': 99,
#   'answer': 'Vanderbilt University'},
#  {'score': 0.9939728379249573,
#   'start': 97,
#   'end': 108,
#   'answer': 'John Howard'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.5314772725105286,
#   'start': 578,
#   'end': 604,
#   'answer': 'The European Go Federation'},
#  {'score': 0.4463198184967041,
#   'start': 762,
#   'end': 823,
#   'answer': 'Associate Justice of the Massachusetts Supreme Judicial Court'},
#  {'score': 0.822155237197876, 'start': 0, 'end': 7, 'answer': 'Outline'},
#  {'score': 0.9734187126159668, 'start': 0, 'end': 4, 'answer': 'Caux'},
#  {'score': 0.1934797167778015,
#   'start': 58,
#   'end': 107,
#   'answer': 'Shin Corporation\nThai Public Broadcasting Service'},
#  {'score': 0.9661557674407959, 'start': 42, 'end': 48, 'answer': 'Canada'},
#  'Sorry, answer not found!',
#  {'score': 0.3904978036880493, 'start': 232, 'end': 240, 'answer': 'idolatry'},
#  'Sorry, answer not found!',
#  {'score': 0.712395429611206, 'start': 0, 'end': 7, 'answer': 'Outline'},
#  {'score': 0.5895850658416748,
#   'start': 392,
#   'end': 406,
#   'answer': 'pearl industry'},
#  'Sorry, answer not found!',
#  {'score': 0.5057166218757629,
#   'start': 0,
#   'end': 18,
#   'answer': 'Outline of England'},
#  {'score': 0.4001031517982483,
#   'start': 1082,
#   'end': 1108,
#   'answer': 'Allegro Barbaro Re-Release'},
#  'Sorry, answer not found!',
#  {'score': 0.9951684474945068,
#   'start': 169,
#   'end': 181,
#   'answer': 'Allan Nevins'},
#  'Sorry, answer not found!',
#  {'score': 0.9740498661994934,
#   'start': 244,
#   'end': 257,
#   'answer': 'Mercer Island'},
#  'Sorry, answer not found!',
#  {'score': 0.3420148193836212,
#   'start': 702,
#   'end': 723,
#   'answer': 'Virgin Mary and Child'},
#  {'score': 0.899649977684021, 'start': 70, 'end': 80, 'answer': 'Metropolis'},
#  {'score': 0.4952206015586853,
#   'start': 14,
#   'end': 36,
#   'answer': 'San Francisco Bay Area'},
#  {'score': 0.7789783477783203,
#   'start': 0,
#   'end': 14,
#   'answer': 'Parañaque City'},
#  'Sorry, answer not found!',
#  {'score': 0.9483316540718079, 'start': 38, 'end': 46, 'answer': 'Colorado'},
#  'Sorry, answer not found!',
#  {'score': 0.9853417873382568,
#   'start': 381,
#   'end': 392,
#   'answer': 'Leo Deutsch'},
#  {'score': 0.6192604303359985,
#   'start': 0,
#   'end': 17,
#   'answer': 'Bili ape\nHumanzee'},
#  'Sorry, answer not found!',
#  {'score': 0.026190757751464844,
#   'start': 1521,
#   'end': 1541,
#   'answer': 'Berkeley, California'},
#  {'score': 0.4177922308444977,
#   'start': 111,
#   'end': 125,
#   'answer': 'Leicester City'},
#  {'score': 0.22338257730007172, 'start': 61, 'end': 65, 'answer': '2004'},
#  {'score': 0.3666938245296478,
#   'start': 17,
#   'end': 41,
#   'answer': 'Indian National Congress'},
#  {'score': 0.9932328462600708, 'start': 15, 'end': 23, 'answer': 'American'},
#  {'score': 0.8588789701461792,
#   'start': 211,
#   'end': 227,
#   'answer': 'Persian Gulf War'},
#  {'score': 0.855255126953125,
#   'start': 35,
#   'end': 54,
#   'answer': 'Outline of Michigan'},
#  {'score': 0.7110498547554016, 'start': 33, 'end': 43, 'answer': 'SodaStream'},
#  {'score': 0.8162361979484558,
#   'start': 0,
#   'end': 13,
#   'answer': 'Tuolumne Peak'},
#  {'score': 0.32883384823799133,
#   'start': 34,
#   'end': 49,
#   'answer': 'Wayback Machine'},
#  {'score': 0.999214231967926, 'start': 18, 'end': 26, 'answer': 'Nebraska'},
#  'Sorry, answer not found!',
#  {'score': 0.6955567598342896,
#   'start': 103,
#   'end': 115,
#   'answer': 'Pennsylvania'},
#  {'score': 0.8805733323097229,
#   'start': 1894,
#   'end': 1911,
#   'answer': 'Michael Bloomberg'},
#  {'score': 0.8264217376708984,
#   'start': 240,
#   'end': 253,
#   'answer': '1976 and 1977'},
#  {'score': 0.9138578176498413,
#   'start': 1692,
#   'end': 1701,
#   'answer': 'Pam Brady'},
#  {'score': 0.10267645120620728,
#   'start': 1140,
#   'end': 1150,
#   'answer': 'Yuki Nakai'},
#  {'score': 0.6767648458480835,
#   'start': 20,
#   'end': 33,
#   'answer': 'New Testament'},
#  {'score': 0.7289456129074097,
#   'start': 75,
#   'end': 91,
#   'answer': 'Upstate New York'},
#  {'score': 0.9769517183303833,
#   'start': 358,
#   'end': 369,
#   'answer': 'Roger Bacon'},
#  'Sorry, answer not found!',
#  {'score': 0.7806292772293091,
#   'start': 393,
#   'end': 427,
#   'answer': 'Chief Justice of the United States'},
#  {'score': 0.9952875971794128,
#   'start': 781,
#   'end': 796,
#   'answer': 'Brandon Frazier'},
#  {'score': 0.49160274863243103,
#   'start': 1035,
#   'end': 1077,
#   'answer': 'president of the Staten Island Railway Co.'},
#  {'score': 0.9238070845603943, 'start': 63, 'end': 71, 'answer': 'Honolulu'},
#  {'score': 0.4608718156814575,
#   'start': 85,
#   'end': 122,
#   'answer': "sacred texts of the world's religions"},
#  {'score': 0.15878325700759888,
#   'start': 362,
#   'end': 400,
#   'answer': 'resigned his commission on 1 July 1931'},
#  {'score': 0.9126332402229309,
#   'start': 263,
#   'end': 281,
#   'answer': 'Major League Rugby'},
#  {'score': 0.8949130773544312, 'start': 18, 'end': 26, 'answer': 'Syracuse'},
#  {'score': 0.9807555079460144, 'start': 24, 'end': 33, 'answer': 'St. Louis'},
#  'Sorry, answer not found!',
#  {'score': 0.717311680316925,
#   'start': 0,
#   'end': 16,
#   'answer': 'Cinema of Sweden'},
#  {'score': 0.714201033115387,
#   'start': 63,
#   'end': 75,
#   'answer': 'Pennsylvania'},
#  {'score': 0.6549074053764343,
#   'start': 130,
#   'end': 140,
#   'answer': 'Radio Logs'},
#  'Sorry, answer not found!',
#  {'score': 0.9915501475334167, 'start': 63, 'end': 73, 'answer': 'Greenpeace'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.33223000168800354,
#   'start': 24,
#   'end': 47,
#   'answer': 'Football\nFootball field'},
#  {'score': 0.7387192845344543, 'start': 143, 'end': 149, 'answer': 'Shasta'},
#  {'score': 0.5788911581039429, 'start': 24, 'end': 29, 'answer': 'Dylan'},
#  {'score': 0.6174647808074951,
#   'start': 346,
#   'end': 377,
#   'answer': 'the Chinese Minority, and China'},
#  {'score': 0.4812842905521393,
#   'start': 1313,
#   'end': 1335,
#   'answer': 'Liverpool City Council'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.757579505443573,
#   'start': 0,
#   'end': 36,
#   'answer': 'The World Register of Marine Species'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.4605877697467804,
#   'start': 0,
#   'end': 28,
#   'answer': 'Forth to Firth Canal Pathway'},
#  {'score': 0.8788977265357971,
#   'start': 0,
#   'end': 16,
#   'answer': 'Marika Gombitová'},
#  {'score': 4.5283672989171464e-07, 'start': 86, 'end': 90, 'answer': '2015'},
#  'Sorry, answer not found!',
#  {'score': 0.47491705417633057,
#   'start': 221,
#   'end': 275,
#   'answer': 'Politicians from across the spectrum of Indian parties'},
#  {'score': 0.9455826282501221,
#   'start': 154,
#   'end': 168,
#   'answer': 'Max Bialystock'},
#  {'score': 0.25152987241744995,
#   'start': 0,
#   'end': 33,
#   'answer': 'Cascade Range\nChiwaukum Mountains'},
#  {'score': 0.7523787617683411,
#   'start': 81,
#   'end': 106,
#   'answer': 'Charles Ellsworth Goodell'},
#  {'score': 0.687219500541687,
#   'start': 10,
#   'end': 35,
#   'answer': 'White Station High School'},
#  {'score': 0.4478267729282379,
#   'start': 0,
#   'end': 50,
#   'answer': 'Damascus Document\nList of World Heritage in Danger'},
#  {'score': 0.919374406337738,
#   'start': 0,
#   'end': 22,
#   'answer': 'Literature and Ecology'},
#  {'score': 0.6971186399459839,
#   'start': 535,
#   'end': 548,
#   'answer': 'Hockey Canada'},
#  'Sorry, answer not found!',
#  {'score': 0.7855938673019409, 'start': 1412, 'end': 1417, 'answer': 'Allie'},
#  {'score': 0.9152074456214905,
#   'start': 504,
#   'end': 529,
#   'answer': 'Macosa and General Motors'},
#  {'score': 0.9063720107078552, 'start': 206, 'end': 211, 'answer': 'women'},
#  {'score': 0.9283623695373535,
#   'start': 76,
#   'end': 109,
#   'answer': 'Seattle-Yakima-Moses Lake-Spokane'},
#  {'score': 0.5585362911224365,
#   'start': 256,
#   'end': 269,
#   'answer': 'New York Alki'},
#  {'score': 0.6856468319892883,
#   'start': 821,
#   'end': 835,
#   'answer': 'Victoria Falls'},
#  {'score': 0.8138757944107056,
#   'start': 9,
#   'end': 33,
#   'answer': 'U.S. News & World Report'},
#  {'score': 0.5945677161216736, 'start': 62, 'end': 69, 'answer': 'Alabama'},
#  {'score': 0.7141615748405457,
#   'start': 354,
#   'end': 366,
#   'answer': 'Jackson Hole'},
#  {'score': 0.34000226855278015,
#   'start': 101,
#   'end': 111,
#   'answer': 'Enterprise'},
#  'Sorry, answer not found!',
#  {'score': 0.6548501253128052,
#   'start': 18,
#   'end': 35,
#   'answer': 'Dr. Josef Mengele'},
#  {'score': 0.8093253970146179, 'start': 0, 'end': 4, 'answer': 'OECD'},
#  {'score': 0.827690839767456,
#   'start': 53,
#   'end': 75,
#   'answer': 'North Caucasus Railway'},
#  {'score': 0.7134590148925781,
#   'start': 140,
#   'end': 156,
#   'answer': 'General Managers'},
#  {'score': 0.9906339645385742,
#   'start': 137,
#   'end': 150,
#   'answer': 'Bill Mitchell'},
#  {'score': 0.833971381187439,
#   'start': 524,
#   'end': 537,
#   'answer': 'Lajos Kossuth'},
#  'Sorry, answer not found!',
#  {'score': 0.11069504171609879,
#   'start': 1298,
#   'end': 1331,
#   'answer': "mixed with the show's theme music"},
#  {'score': 0.4047195315361023, 'start': 37, 'end': 44, 'answer': 'Bengali'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.721113920211792,
#   'start': 75,
#   'end': 88,
#   'answer': 'Zambezi River'},
#  {'score': 0.06229384243488312,
#   'start': 711,
#   'end': 719,
#   'answer': 'Helsinki'},
#  {'score': 0.29030725359916687, 'start': 28, 'end': 34, 'answer': 'French'},
#  {'score': 0.2260075956583023,
#   'start': 62,
#   'end': 89,
#   'answer': 'Yıldız Technical University'},
#  'Sorry, answer not found!',
#  {'score': 0.3826320767402649, 'start': 23, 'end': 27, 'answer': '2002'},
#  {'score': 0.9869558811187744, 'start': 238, 'end': 243, 'answer': 'EVRAZ'},
#  {'score': 0.5726779699325562,
#   'start': 1661,
#   'end': 1681,
#   'answer': 'The Furchester Hotel'},
#  {'score': 0.20388087630271912,
#   'start': 415,
#   'end': 430,
#   'answer': '"Promised Land"'},
#  {'score': 0.9680138826370239,
#   'start': 17,
#   'end': 36,
#   'answer': 'National Geographic'},
#  'Sorry, answer not found!',
#  {'score': 0.9949449896812439, 'start': 0, 'end': 6, 'answer': 'Adidas'},
#  {'score': 0.6173311471939087,
#   'start': 371,
#   'end': 398,
#   'answer': 'Rocky Mountains of Colorado'},
#  {'score': 0.9058725237846375, 'start': 73, 'end': 79, 'answer': 'NASCAR'},
#  {'score': 0.9790892601013184,
#   'start': 3225,
#   'end': 3236,
#   'answer': 'Anawan Road'},
#  {'score': 0.9939690828323364, 'start': 35, 'end': 43, 'answer': 'Nigerian'},
#  {'score': 0.44086533784866333,
#   'start': 460,
#   'end': 468,
#   'answer': 'comedian'},
#  {'score': 0.6875380873680115,
#   'start': 88,
#   'end': 113,
#   'answer': 'Al Hirt and Pete Fountain'},
#  {'score': 0.9587812423706055,
#   'start': 1902,
#   'end': 1910,
#   'answer': 'Doniphan'},
#  {'score': 0.16519419848918915,
#   'start': 36,
#   'end': 53,
#   'answer': 'orbital launchers'},
#  'Sorry, answer not found!',
#  {'score': 0.04158316180109978,
#   'start': 141,
#   'end': 201,
#   'answer': 'Kovacs was found guilty and later fined for reckless driving'},
#  {'score': 0.4700030982494354,
#   'start': 144,
#   'end': 168,
#   'answer': 'federal judicial circuit'},
#  {'score': 0.9324557185173035, 'start': 0, 'end': 5, 'answer': 'Tange'},
#  {'score': 0.9682670831680298, 'start': 105, 'end': 111, 'answer': 'Hawaii'},
#  'Sorry, answer not found!',
#  {'score': 0.18021032214164734, 'start': 29, 'end': 33, 'answer': '1947'},
#  {'score': 0.5639640092849731,
#   'start': 87,
#   'end': 99,
#   'answer': 'Dinaric Alps'},
#  'Sorry, answer not found!',
#  {'score': 0.5970162153244019,
#   'start': 1724,
#   'end': 1735,
#   'answer': 'Nobel Prize'},
#  'Sorry, answer not found!',
#  {'score': 0.9903286695480347,
#   'start': 3383,
#   'end': 3390,
#   'answer': 'Qusquam'},
#  {'score': 0.7934473752975464,
#   'start': 99,
#   'end': 123,
#   'answer': 'Canadian Labour Congress'},
#  {'score': 0.969528079032898,
#   'start': 1527,
#   'end': 1535,
#   'answer': 'GM India'},
#  {'score': 0.9831922054290771,
#   'start': 66,
#   'end': 78,
#   'answer': 'Random House'},
#  {'score': 0.9533537030220032,
#   'start': 358,
#   'end': 368,
#   'answer': 'Chip Foose'},
#  {'score': 0.8248375654220581,
#   'start': 116,
#   'end': 130,
#   'answer': 'Patrick Tambay'},
#  {'score': 0.9561334848403931,
#   'start': 0,
#   'end': 15,
#   'answer': 'Gabrielle Union'},
#  {'score': 0.2920142412185669,
#   'start': 57,
#   'end': 68,
#   'answer': 'Connecticut'},
#  {'score': 0.4462684094905853,
#   'start': 100,
#   'end': 124,
#   'answer': 'Competitive Cheerleading'},
#  {'score': 0.9681431651115417,
#   'start': 100,
#   'end': 116,
#   'answer': 'listening device'},
#  {'score': 0.8011760115623474,
#   'start': 144,
#   'end': 171,
#   'answer': 'political rallies and fairs'},
#  {'score': 0.9585197567939758,
#   'start': 36,
#   'end': 52,
#   'answer': 'House and Senate'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.767568051815033,
#   'start': 37,
#   'end': 51,
#   'answer': 'American Samoa'},
#  {'score': 0.45457491278648376,
#   'start': 2754,
#   'end': 2771,
#   'answer': 'political enemies'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.3821515738964081,
#   'start': 37,
#   'end': 53,
#   'answer': 'Yeovil Town F.C.'},
#  {'score': 0.9965099096298218, 'start': 20, 'end': 30, 'answer': 'Jay Gorney'},
#  {'score': 0.8023257255554199,
#   'start': 1279,
#   'end': 1287,
#   'answer': 'Cox Farm'},
#  'Sorry, answer not found!',
#  {'score': 0.641626238822937, 'start': 0, 'end': 6, 'answer': 'Museum'},
#  {'score': 0.731683075428009,
#   'start': 75,
#   'end': 99,
#   'answer': 'Virginia\nHampton Pirates'},
#  {'score': 0.4901830852031708,
#   'start': 0,
#   'end': 12,
#   'answer': 'ny (digraph)'},
#  {'score': 0.41340628266334534,
#   'start': 3909,
#   'end': 3917,
#   'answer': 'Slovakia'},
#  {'score': 0.9220935702323914,
#   'start': 65,
#   'end': 77,
#   'answer': 'chess player'},
#  {'score': 0.09796715527772903, 'start': 0, 'end': 6, 'answer': 'Ultima'},
#  {'score': 0.6049931645393372, 'start': 866, 'end': 872, 'answer': 'Gloria'},
#  'Sorry, answer not found!',
#  {'score': 0.7608541250228882, 'start': 48, 'end': 58, 'answer': 'Physiology'},
#  'Sorry, answer not found!',
#  {'score': 0.5015912055969238, 'start': 119, 'end': 123, 'answer': '2004'},
#  {'score': 0.9577594995498657,
#   'start': 66,
#   'end': 87,
#   'answer': 'MINExpo International'},
#  'Sorry, answer not found!',
#  {'score': 0.7393178939819336,
#   'start': 194,
#   'end': 218,
#   'answer': "Sarajevo's Bare Cemetery"},
#  {'score': 0.8170872330665588,
#   'start': 50,
#   'end': 61,
#   'answer': 'communicant'},
#  {'score': 0.9741026163101196, 'start': 61, 'end': 67, 'answer': 'Boston'},
#  {'score': 0.8089514374732971,
#   'start': 0,
#   'end': 32,
#   'answer': 'Johann Anastasius Freylinghausen'},
#  {'score': 0.8098393678665161, 'start': 0, 'end': 5, 'answer': 'Lions'},
#  'Sorry, answer not found!',
#  {'score': 0.7052887678146362,
#   'start': 53,
#   'end': 66,
#   'answer': 'Dornier Do 31'},
#  {'score': 0.10147322714328766,
#   'start': 761,
#   'end': 796,
#   'answer': 'horse riding, shooting and dancing.'},
#  {'score': 0.5152155756950378,
#   'start': 216,
#   'end': 229,
#   'answer': 'United States'},
#  {'score': 0.4650290310382843,
#   'start': 1,
#   'end': 25,
#   'answer': '2. BC Baco Noir wineries'},
#  {'score': 0.9058042764663696,
#   'start': 156,
#   'end': 185,
#   'answer': 'Calvin Stone and Lewis Terman'},
#  {'score': 0.6363304257392883,
#   'start': 40,
#   'end': 61,
#   'answer': 'Connecticut Statesman'},
#  'Sorry, answer not found!',
#  {'score': 0.11258861422538757, 'start': 828, 'end': 835, 'answer': 'Danelaw'},
#  {'score': 0.9156815409660339,
#   'start': 126,
#   'end': 140,
#   'answer': 'The New Yorker'},
#  {'score': 0.09796715527772903, 'start': 0, 'end': 6, 'answer': 'Ultima'},
#  {'score': 0.9339450597763062, 'start': 21, 'end': 29, 'answer': 'Morinish'},
#  {'score': 0.4155014753341675,
#   'start': 0,
#   'end': 14,
#   'answer': 'Hegde (village'},
#  {'score': 0.8157278895378113,
#   'start': 338,
#   'end': 370,
#   'answer': 'Don Mueang International Airport'},
#  'Sorry, answer not found!',
#  {'score': 0.7222778797149658,
#   'start': 59,
#   'end': 71,
#   'answer': 'Brad Paisley'},
#  {'score': 0.931625247001648, 'start': 3173, 'end': 3177, 'answer': 'Navy'},
#  {'score': 0.18695558607578278, 'start': 84, 'end': 90, 'answer': '96.95%'},
#  'Sorry, answer not found!',
#  {'score': 0.2537599205970764, 'start': 2415, 'end': 2420, 'answer': 'three'},
#  {'score': 0.9541671872138977,
#   'start': 478,
#   'end': 502,
#   'answer': 'Indian National Congress'},
#  {'score': 0.6105539798736572,
#   'start': 818,
#   'end': 829,
#   'answer': 'King Alfred'},
#  {'score': 0.37148749828338623, 'start': 0, 'end': 10, 'answer': 'Ahmet Ataç'},
#  {'score': 0.9439929127693176,
#   'start': 0,
#   'end': 15,
#   'answer': 'Dominic\nDomenic'},
#  {'score': 0.19869068264961243, 'start': 170, 'end': 175, 'answer': 'Chess'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.8263635039329529,
#   'start': 263,
#   'end': 274,
#   'answer': 'Young Thugz'},
#  {'score': 0.958109438419342, 'start': 21, 'end': 25, 'answer': 'UCLA'},
#  'Sorry, answer not found!',
#  {'score': 0.30305808782577515, 'start': 27, 'end': 33, 'answer': 'editor'},
#  {'score': 0.1141384169459343,
#   'start': 20,
#   'end': 63,
#   'answer': '2014 documentary about politics in Zimbabwe'},
#  {'score': 0.9322380423545837, 'start': 70, 'end': 80, 'answer': 'Metropolis'},
#  {'score': 0.990305483341217, 'start': 19, 'end': 26, 'answer': 'Karachi'},
#  {'score': 0.698517918586731,
#   'start': 5,
#   'end': 19,
#   'answer': 'External links'},
#  {'score': 0.49334418773651123,
#   'start': 24,
#   'end': 47,
#   'answer': 'Football\nFootball field'},
#  {'score': 0.9580466747283936,
#   'start': 84,
#   'end': 99,
#   'answer': 'The Drama Kings'},
#  {'score': 0.43626290559768677,
#   'start': 35,
#   'end': 73,
#   'answer': 'All-time Vancouver Whitecaps FC roster'},
#  {'score': 0.584484875202179,
#   'start': 80,
#   'end': 96,
#   'answer': 'Marthe Cnockaert'},
#  'Sorry, answer not found!',
#  {'score': 0.5310001373291016,
#   'start': 205,
#   'end': 223,
#   'answer': 'major contributors'},
#  {'score': 0.9653978943824768,
#   'start': 19,
#   'end': 34,
#   'answer': 'Walter Tuckwell'},
#  {'score': 0.9860261082649231,
#   'start': 1692,
#   'end': 1701,
#   'answer': 'Pam Brady'},
#  {'score': 0.8991826176643372, 'start': 0, 'end': 9, 'answer': 'San Diego'},
#  {'score': 0.9031612277030945,
#   'start': 578,
#   'end': 591,
#   'answer': 'Thomas Taylor'},
#  {'score': 0.22658149898052216,
#   'start': 0,
#   'end': 40,
#   'answer': 'He is married to the former Susan Hughes'},
#  {'score': 0.47014352679252625, 'start': 15, 'end': 23, 'answer': 'Congress'},
#  {'score': 0.824488639831543,
#   'start': 557,
#   'end': 573,
#   'answer': 'Phillips Academy'},
#  {'score': 0.3148770034313202,
#   'start': 27,
#   'end': 50,
#   'answer': 'Lee Allen, Putnam, 1961'},
#  {'score': 0.4930194318294525,
#   'start': 644,
#   'end': 680,
#   'answer': 'U.S. Naval Intelligence Reserve Unit'},
#  'Sorry, answer not found!',
#  {'score': 0.5189027190208435,
#   'start': 79,
#   'end': 102,
#   'answer': 'Smithsonian Institution'},
#  {'score': 0.33119210600852966,
#   'start': 737,
#   'end': 756,
#   'answer': 'Governor Strickland'},
#  {'score': 0.354633629322052,
#   'start': 229,
#   'end': 255,
#   'answer': '90th pick of the NBA draft'},
#  {'score': 0.9754975438117981,
#   'start': 1377,
#   'end': 1384,
#   'answer': 'Germany'},
#  {'score': 0.24592402577400208,
#   'start': 0,
#   'end': 15,
#   'answer': 'Hegde (village)'},
#  {'score': 0.4907703399658203,
#   'start': 113,
#   'end': 153,
#   'answer': 'the Köppen Climate Classification system'},
#  {'score': 0.5464295744895935,
#   'start': 677,
#   'end': 695,
#   'answer': 'Williams, Marjorie'},
#  'Sorry, answer not found!',
#  {'score': 0.9899275898933411,
#   'start': 100,
#   'end': 111,
#   'answer': 'Pu Luo Jong'},
#  {'score': 0.8744758367538452,
#   'start': 35,
#   'end': 54,
#   'answer': 'Outline of Kentucky'},
#  'Sorry, answer not found!',
#  {'score': 0.8212313055992126,
#   'start': 156,
#   'end': 172,
#   'answer': 'Discworld novels'},
#  {'score': 0.7630035877227783, 'start': 0, 'end': 6, 'answer': 'Moscow'},
#  {'score': 0.9313592314720154,
#   'start': 9,
#   'end': 45,
#   'answer': 'Bangladesh, Bhutan, India, and Nepal'},
#  {'score': 0.995834469795227,
#   'start': 2559,
#   'end': 2567,
#   'answer': 'Leo Kahn'},
#  {'score': 0.7887549996376038,
#   'start': 0,
#   'end': 35,
#   'answer': 'Sherry L. Hoppe and Dennie B. Burke'},
#  {'score': 0.44011619687080383,
#   'start': 327,
#   'end': 354,
#   'answer': 'Garci Rodríguez de Montalvo'},
#  'Sorry, answer not found!',
#  {'score': 0.9356694221496582, 'start': 14, 'end': 18, 'answer': '1951'},
#  {'score': 0.7223976254463196,
#   'start': 120,
#   'end': 133,
#   'answer': 'Pat Gallagher'},
#  {'score': 0.6299113631248474,
#   'start': 78,
#   'end': 91,
#   'answer': 'Carroll\nCarol'},
#  'Sorry, answer not found!',
#  {'score': 0.4408949017524719,
#   'start': 47,
#   'end': 70,
#   'answer': 'male, female and junior'},
#  {'score': 0.8006651997566223,
#   'start': 1659,
#   'end': 1676,
#   'answer': 'Katz Broadcasting'},
#  {'score': 0.1055801585316658,
#   'start': 25,
#   'end': 55,
#   'answer': 'uncredited script doctor, 2013'},
#  {'score': 0.8327627182006836,
#   'start': 39,
#   'end': 75,
#   'answer': 'Social Business - Global Initiatives'},
#  {'score': 0.45100006461143494,
#   'start': 11032,
#   'end': 11055,
#   'answer': 'World Champion Openings'},
#  {'score': 0.5903003215789795,
#   'start': 66,
#   'end': 94,
#   'answer': 'several counties and regions'},
#  {'score': 0.827680230140686,
#   'start': 254,
#   'end': 273,
#   'answer': 'Geneva, Switzerland'},
#  {'score': 0.18410992622375488,
#   'start': 93,
#   'end': 103,
#   'answer': 'Tom Sawyer'},
#  {'score': 0.7548052072525024,
#   'start': 36,
#   'end': 50,
#   'answer': 'Houston Astros'},
#  {'score': 0.8588224053382874,
#   'start': 4370,
#   'end': 4385,
#   'answer': 'Samajwadi Party'},
#  {'score': 0.1243322491645813,
#   'start': 549,
#   'end': 565,
#   'answer': 'three colleagues'},
#  {'score': 0.9053708910942078,
#   'start': 782,
#   'end': 800,
#   'answer': 'India and Pakistan'},
#  'Sorry, answer not found!',
#  'Sorry, answer not found!',
#  {'score': 0.9968640208244324, 'start': 0, 'end': 3, 'answer': 'Rav'},
#  {'score': 0.9111245274543762,
#   'start': 1178,
#   'end': 1196,
#   'answer': 'Central Park South'},
#  {'score': 0.9793833494186401, 'start': 313, 'end': 316, 'answer': 'law'},
#  {'score': 0.4373621642589569,
#   'start': 59,
#   'end': 79,
#   'answer': 'Camino de Costa Rica'},
#  'Sorry, answer not found!',
#  {'score': 0.7678975462913513,
#   'start': 0,
#   'end': 16,
#   'answer': "Brunckow's Cabin"},
#  {'score': 0.05398937687277794,
#   'start': 0,
#   'end': 14,
#   'answer': 'Bogobiri house'},
#  {'score': 0.5259599685668945,
#   'start': 42,
#   'end': 59,
#   'answer': 'Timeline of radio'},
#  {'score': 0.23751729726791382, 'start': 26, 'end': 34, 'answer': 'literary'},
#  'Sorry, answer not found!',
#  {'score': 0.9987471699714661, 'start': 293, 'end': 301, 'answer': 'Buddhist'},
#  {'score': 0.9969832897186279, 'start': 346, 'end': 351, 'answer': 'Kenya'},
#  {'score': 0.27004387974739075,
#   'start': 59,
#   'end': 71,
#   'answer': 'South Africa'},
#  {'score': 0.9930528998374939,
#   'start': 0,
#   'end': 26,
#   'answer': 'Sister cities\nPartnerships'},
#  'Sorry, answer not found!',
#  {'score': 0.6132670640945435,
#   'start': 244,
#   'end': 258,
#   'answer': 'London England'},
#  {'score': 0.7742375731468201, 'start': 84, 'end': 93, 'answer': 'Edinburgh'},
#  {'score': 0.5614617466926575,
#   'start': 154,
#   'end': 171,
#   'answer': 'Microsoft Windows'},
#  {'score': 0.8667477965354919,
#   'start': 10,
#   'end': 36,
#   'answer': 'Prince George of Cambridge'},
#  {'score': 0.8055750727653503,
#   'start': 148,
#   'end': 175,
#   'answer': 'Airports Authority of India'},
#  'Sorry, answer not found!',
#  {'score': 0.9610171914100647,
#   'start': 90,
#   'end': 109,
#   'answer': 'George Westinghouse'},
#  {'score': 0.053338587284088135,
#   'start': 227,
#   'end': 248,
#   'answer': 'University of Chicago'},
#  {'score': 0.08003631234169006, 'start': 0, 'end': 7, 'answer': 'Versace'},
#  {'score': 0.8065597414970398, 'start': 6, 'end': 17, 'answer': 'Mario media'},
#  {'score': 0.21044571697711945,
#   'start': 0,
#   'end': 53,
#   'answer': 'Printing House Row District — also in Central Chicago'},
#  {'score': 0.5748212337493896,
#   'start': 545,
#   'end': 572,
#   'answer': 'Pre-revolutionary interiors'},
#  {'score': 0.5026353001594543,
#   'start': 1686,
#   'end': 1713,
#   'answer': 'Lawrence Erlbaum Associates'},
#  'Sorry, answer not found!',
#  {'score': 0.6797987818717957,
#   'start': 2363,
#   'end': 2370,
#   'answer': 'Solunar'},
#  {'score': 0.9243431091308594,
#   'start': 96,
#   'end': 154,
#   'answer': 'William Smith (1707–1783) and Elizabeth (née Quincy) Smith'},
#  'Sorry, answer not found!',
#  {'score': 0.43500158190727234,
#   'start': 2240,
#   'end': 2303,
#   'answer': 'African Bach, Softsword, The Classical Connection 2 and Prayers'},
#  'Sorry, answer not found!',
#  {'score': 0.6343684196472168,
#   'start': 140,
#   'end': 156,
#   'answer': 'General Managers'},
#  {'score': 0.7823678255081177,
#   'start': 80,
#   'end': 96,
#   'answer': 'The Suns Gorilla'},
#  {'score': 0.6284792423248291,
#   'start': 263,
#   'end': 281,
#   'answer': 'Major League Rugby'},
#  {'score': 0.6499612927436829,
#   'start': 0,
#   'end': 15,
#   'answer': 'Coleford, I. C.'},
#  'Sorry, answer not found!',
#  {'score': 0.8983991742134094,
#   'start': 29,
#   'end': 44,
#   'answer': 'Katsura Hoshino'},
#  {'score': 0.9524502754211426, 'start': 0, 'end': 6, 'answer': 'La Val'},
#  {'score': 0.12714003026485443,
#   'start': 62,
#   'end': 92,
#   'answer': 'St Lucia Squad - 2014\nSt Lucia'},
#  'Sorry, answer not found!',
#  {'score': 0.42022329568862915,
#   'start': 59,
#   'end': 79,
#   'answer': 'Camino de Costa Rica'},
#  {'score': 0.9959331750869751,
#   'start': 23,
#   'end': 35,
#   'answer': 'Jägermeister'},
#  {'score': 0.5244054794311523,
#   'start': 274,
#   'end': 298,
#   'answer': 'administrative assistant'},
#  {'score': 0.27528253197669983, 'start': 26, 'end': 32, 'answer': 'eighth'},
#  {'score': 0.8678445219993591,
#   'start': 420,
#   'end': 436,
#   'answer': 'Lewis University'},
#  {'score': 0.59919673204422, 'start': 0, 'end': 7, 'answer': 'Antoine'},
#  'Sorry, answer not found!',
#  {'score': 0.9687831997871399,
#   'start': 763,
#   'end': 806,
#   'answer': 'Batista, Shelton Benjamin, and Josh Mathews'},
#  {'score': 0.20974883437156677,
#   'start': 275,
#   'end': 287,
#   'answer': 'GP de Mexico'},
#  {'score': 0.6862164735794067,
#   'start': 20,
#   'end': 53,
#   'answer': 'An Account of the Polynesian Race'},
#  {'score': 0.4457152485847473, 'start': 22, 'end': 26, 'answer': 'Joey'},
#  {'score': 0.8208103775978088,
#   'start': 5,
#   'end': 19,
#   'answer': 'External links'},
#  {'score': 0.7288751006126404, 'start': 92, 'end': 99, 'answer': 'Seattle'},
#  'Sorry, answer not found!',
#  {'score': 0.8541057109832764, 'start': 184, 'end': 191, 'answer': 'Namibia'},
#  {'score': 0.8571990132331848, 'start': 99, 'end': 105, 'answer': 'Giants'},
#  {'score': 0.27496039867401123,
#   'start': 17,
#   'end': 41,
#   'answer': 'Indian National Congress'},
#  {'score': 0.721591591835022,
#   'start': 11,
#   'end': 28,
#   'answer': 'real estate taxes'},
#  {'score': 0.28381794691085815,
#   'start': 33,
#   'end': 61,
#   'answer': 'International Ski Federation'},
#  {'score': 0.8693192601203918,
#   'start': 5,
#   'end': 17,
#   'answer': 'Bibliography'},
#  {'score': 0.7962615489959717,
#   'start': 42,
#   'end': 61,
#   'answer': 'Toronto Maple Leafs'}]

# %%
answers_text = [item['answer'] if type(item) != str else item for item in answers]

# %%
# store answers
questions['wiki_answer'] =  answers_text

# %%
questions.to_csv('../data/questions_answered.csv')
